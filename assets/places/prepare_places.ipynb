# %%
import pandas

# %%
# federal states
fs = pandas.read_csv('/workspaces/thesis/assets/places/1_federal_states.csv')
fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nuts_code   16 non-null     object
#  1   name        16 non-null     object
#  2   geom        16 non-null     object
#  3   country_id  16 non-null     object
# dtypes: object(4)
# memory usage: 644.0+ bytes

# %%
# planning regions
fs = pandas.read_csv('/workspaces/thesis/assets/places/2_planning_regions.csv')
fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 6 columns):
# ...

# %%
# counties
fs = pandas.read_csv('/workspaces/thesis/assets/places/3_counties.csv')
fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nuts_code         401 non-null    object
#  1   name              401 non-null    object
#  2   same_as_parent    401 non-null    bool
#  3   geom              401 non-null    object
#  4   country_id        401 non-null    object
#  5   federal_state_id  401 non-null    object
# dtypes: bool(1), object(5)
# memory usage: 16.2+ KB

# %%
# administrative units
fs = pandas.read_csv('/workspaces/thesis/assets/places/4_administrative_units.csv')
fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4577 entries, 0 to 4576
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   extended_nuts_code  4577 non-null   object
#  1   name                4577 non-null   object
#  2   geom                4577 non-null   object
#  3   country_id          4577 non-null   object
#  4   federal_state_id    4577 non-null   object
#  5   planning_region_id  4577 non-null   object
#  6   county_id           4577 non-null   object
# dtypes: object(7)
# memory usage: 250.4+ KB

# %%
# local administrative units
fs = pandas.read_csv('/workspaces/thesis/assets/places/5_local_administrative_units.csv')
fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11007 entries, 0 to 11006
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gisco_code                11007 non-null  object
#  1   name                      11007 non-null  object
#  2   same_as_parent            11007 non-null  bool
#  3   geom                      11007 non-null  object
#  4   country_id                11007 non-null  object
#  5   county_id                 11007 non-null  object
#  6   federal_state_id          11007 non-null  object
#  7   governmental_district_id  11007 non-null  object
#  8   same_as_parent_pr         11007 non-null  bool
#  9   administrative_unit_id    11007 non-null  object
# dtypes: bool(2), object(8)
# memory usage: 709.6+ KB
